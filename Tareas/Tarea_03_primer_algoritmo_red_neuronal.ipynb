# %% [markdown]
# ![imagenes](logo.png)

# %% [markdown]
# # Tarea 03. Primer algoritmo de una red neuronal

# %% [markdown]
# Toma la red neuronal que vimos en clase:
#
# https://github.com/scidatmath2020/DL_Py_25/blob/main/scripts/mi_primer_red.ipynb
#
# Añade una característica a cada cliente. Es decir, añade un número a cada fila de $X$. Añade dos nuevos clientes. Es decir, añade dos filas a $X$ y dos filas a $y$.

# %% [markdown]
# 1. ¿Cuántas neuronas requiere la capa de entrada? Modifica el código.\\
#
# 2. Como tienes mas neuronas en la capa de entrada, requieres modificar la matriz de pesos de la capa 1. ¿Cómo se tiene que modificar? Haz la modificación. ¿El vector de sesgos debe modificarse? \\
#
# 3. Como cambiaste el número de clientes, ¿cómo queda $B$ para elegir batch gradiente descendente?
#
# 4. Ejecuta el código a 15 épocas para gradiente descendente, estocástico y para minibatch de tamaño 3.
